# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
import numpy as np

# %%
def wait_for_page_to_load(driver, wait):
    title = driver.title
    try:
        wait.until(
            lambda d: d.execute_script("return document.readyState") == "complete"
        )
    except:
        print(f"the webpage \"{title}\" did not get fully loaded")
    else:
        print(f"the webpage {title} did get fully loaded")

# %%
# options
chrome_options = Options()
chrome_options.add_argument("--disable-http2")
chrome_options.add_argument("--incognito")
chrome_options.add_argument("--disable-blink-features=AutomationControlled")
chrome_options.add_argument("--ignore-certificate-errors")
chrome_options.add_argument("--enable-features=NetworkServiceInProcess")
chrome_options.add_argument("--disable-features=NetworkService")
chrome_options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36"
)

# Use the correct path to your downloaded chromedriver
service = Service("C:\\webdrivers\\chromedriver.exe")

# Now start the browser using the specified service
driver = webdriver.Chrome(service=service, options=chrome_options) 

driver.maximize_window()

# explicit wait
wait = WebDriverWait(driver, 5)

# accessing the target webpage
url = "https://www.99acres.com/"
driver.get(url)
wait_for_page_to_load(driver, wait)

# identify and enter text into search bar
try:
	search_bar = wait.until(
		EC.presence_of_element_located((By.XPATH, '//*[@id="keyword2"]'))
	)
except:
	print("Timeout while locating Search Bar.\n")
else:
	search_bar.send_keys("Chennai")
	time.sleep(2)

# selecting valid option from list
try:
	valid_option = wait.until(
		EC.element_to_be_clickable((By.XPATH, '//*[@id="0"]'))
	)
except:
	print("Timeout while locating valid search option.\n")
else:
	valid_option.click()
	time.sleep(2)

# click on Search button
try:
	search_button = wait.until(
		EC.element_to_be_clickable((By.XPATH, '//*[@id="searchform_search_btn"]'))
	)
except:
	print("Timeout while clicking on \"Search\" button.\n")
else:
	search_button.click()
	wait_for_page_to_load(driver, wait)

# adjust the Budget slider
try:
	slider = wait.until(
		EC.element_to_be_clickable((By.XPATH, '//*[@id="budgetLeftFilter_max_node"]'))
	)
except:
	print("Timeout while clicking on Budget slider circle.\n")
else:
	actions = ActionChains(driver)
	(
		actions
		.click_and_hold(slider)
		.move_by_offset(-73, 0)
		.release()
		.perform()
	)
	time.sleep(2)

# filter results to show genuine listings
# 1. Verified
verified = wait.until(
	EC.element_to_be_clickable((By.XPATH, '/html[1]/body[1]/div[1]/div[1]/div[1]/div[4]/div[3]/div[1]/div[3]/section[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[3]/span[1]'))
)
verified.click()
time.sleep(1)

# 2. Ready To Move
ready_to_move = wait.until(
	EC.element_to_be_clickable((By.XPATH, '/html[1]/body[1]/div[1]/div[1]/div[1]/div[4]/div[3]/div[1]/div[3]/section[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[5]/span[1]'))
)
ready_to_move.click()
time.sleep(1)

# moving to the right side to unhide remaining filters
while True:
	try:
		filter_right_button = wait.until(
			EC.presence_of_element_located((By.XPATH, "//i[contains(@class,'iconS_Common_24 icon_upArrow cc__rightArrow')]"))
		)
	except:
		print("Timeout because we have uncovered all filters.\n")
		break
	else:
		filter_right_button.click()
		time.sleep(1)

# 3. With Photos
with_photos = wait.until(
	EC.element_to_be_clickable((By.XPATH, '/html[1]/body[1]/div[1]/div[1]/div[1]/div[4]/div[3]/div[1]/div[3]/section[1]/div[1]/div[1]/div[1]/div[1]/div[2]/div[1]/div[6]/span[1]'))
)
with_photos.click()
time.sleep(1)

# 4. With Videos
with_videos = wait.until(
	EC.element_to_be_clickable((By.XPATH, '/html[1]/body[1]/div[1]/div[1]/div[1]/div[4]/div[3]/div[1]/div[3]/section[1]/div[1]/div[1]/div[1]/div[1]/div[2]/div[1]/div[7]/span[1]'))
)
with_videos.click()
time.sleep(3)

# navigate pages and extract data
data = []
page_count = 0
while True:
	page_count += 1
	try:
		next_page_button = driver.find_element(By.XPATH, "//a[normalize-space()='Next Page >']")
	except:
		print(f"Timeout because we have navigated all the {page_count} pages.\n")
		break
	else:
		try:
			driver.execute_script("window.scrollBy(0, arguments[0].getBoundingClientRect().top - 100);", next_page_button)
			time.sleep(2)
	
			# scraping the data
			rows = driver.find_elements(By.CLASS_NAME, "tupleNew__TupleContent")
			for row in rows:
				# property name
				try:
					name = row.find_element(By.CLASS_NAME, "tupleNew__headingNrera").text
				except:
					name = np.nan

				# property location
				try:
					location = row.find_element(By.CLASS_NAME, "tupleNew__propType").text
				except:
					location = np.nan

				# property price
				try:
					price = row.find_element(By.CLASS_NAME, "tupleNew__priceValWrap").text
				except:
					price = np.nan

				# property area and bhk
				try:
					elements = row.find_elements(By.CLASS_NAME, "tupleNew__area1Type")
				except:
					area, bhk = [np.nan, np.nan]
				else:
					area, bhk = [ele.text for ele in elements]
					
				property = {
					"name": name,
					"location": location,
					"price": price,
					"area": area,
					"bhk": bhk
				}
				data.append(property)
			
			wait.until(
				EC.element_to_be_clickable((By.XPATH, "//a[normalize-space()='Next Page >']"))
			).click()
			time.sleep(50)
		except:
			print("Timeout while clicking on \"Next Page\".\n")

# scraping data from the last page
rows = driver.find_elements(By.CLASS_NAME, "tupleNew__TupleContent")
for row in rows:
	# property name
	try:
		name = row.find_element(By.CLASS_NAME, "tupleNew__headingNrera").text
	except:
		name = np.nan

	# property location
	try:
		location = row.find_element(By.CLASS_NAME, "tupleNew__propType").text
	except:
		location = np.nan

	# property price
	try:
		price = row.find_element(By.CLASS_NAME, "tupleNew__priceValWrap").text
	except:
		price = np.nan

	# property area and bhk
	try:
		elements = row.find_elements(By.CLASS_NAME, "tupleNew__area1Type")
	except:
		area, bhk = [np.nan, np.nan]
	else:
		area, bhk = [ele.text for ele in elements]
					
	property = {
		"name": name,
		"location": location,
		"price": price,
		"area": area,
		"bhk": bhk
	}
	data.append(property)
# Out:
# the webpage India Real Estate Property Site - Buy Sell Rent Properties Portal - 99acres.com did get fully loaded
# the webpage Property in Chennai - Real Estate in Chennai did get fully loaded
# Timeout because we have uncovered all filters.
#
# Timeout while clicking on "Next Page".
#
# Timeout while clicking on "Next Page".
#
# Timeout because we have navigated all the 51 pages.

# %%
data
# Out:
# [{'name': 'on request',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹48 Lac',
#   'area': '764 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RC Adena',
#   'location': '2 BHK Flat in Thirumullaivoyal, Chennai',
#   'price': '₹45 Lac',
#   'area': '820 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Radiance Suprema',
#   'location': '2 BHK Flat in Madhavaram, Chennai',
#   'price': '₹1 Cr',
#   'area': '1,102 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹57.7 Lac',
#   'area': '932 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Shriram Park 63\n3.8',
#   'location': '3 BHK Flat in Perungalathur, Chennai',
#   'price': '₹1.5 Cr',
#   'area': '1,970 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Babu enclave',
#   'location': '3 BHK Flat in Keelkattalai, Chennai',
#   'price': '₹93.79 Lac',
#   'area': '1,218 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Adhith enclave',
#   'location': '3 BHK Flat in Veeramani Nagar, Kovilambakkam',
#   'price': '₹89.17 Lac',
#   'area': '1,158 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹48 Lac',
#   'area': '764 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RC Adena',
#   'location': '2 BHK Flat in Thirumullaivoyal, Chennai',
#   'price': '₹45 Lac',
#   'area': '820 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Radiance Suprema',
#   'location': '2 BHK Flat in Madhavaram, Chennai',
#   'price': '₹1 Cr',
#   'area': '1,102 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹57.7 Lac',
#   'area': '932 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Shriram Park 63\n3.8',
#   'location': '3 BHK Flat in Perungalathur, Chennai',
#   'price': '₹1.5 Cr',
#   'area': '1,970 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Babu enclave',
#   'location': '3 BHK Flat in Keelkattalai, Chennai',
#   'price': '₹93.79 Lac',
#   'area': '1,218 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Adhith enclave',
#   'location': '3 BHK Flat in Veeramani Nagar, Kovilambakkam',
#   'price': '₹89.17 Lac',
#   'area': '1,158 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹57.7 Lac',
#   'area': '933 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'BABU FLATS',
#   'location': '3 BHK Flat in Rose Nagar, Kovilambakkam',
#   'price': '₹95.17 Lac',
#   'area': '1,236 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Adhith residency',
#   'location': '3 BHK Flat in Veeramani Nagar, Kovilambakkam',
#   'price': '₹1.05 Cr',
#   'area': '1,236 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Somu residency',
#   'location': '3 BHK Flat in Rose Nagar, Kovilambakkam',
#   'price': '₹1.03 Cr',
#   'area': '1,218 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Kovur, Chennai, Chennai West',
#   'location': '2 Bedroom House in Kovur, Chennai',
#   'price': '₹78 Lac',
#   'area': '800 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Somu residency',
#   'location': '3 BHK Flat in Keelkattalai, Chennai',
#   'price': '₹89.19 Lac',
#   'area': '1,158 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'ADHITH RESIDENCY',
#   'location': '3 BHK Flat in Kovilambakkam, Chennai',
#   'price': '₹93.79 Lac',
#   'area': '1,218 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'BABU FLATS',
#   'location': '3 BHK Flat in Rose Nagar, Kovilambakkam',
#   'price': '₹92.99 Lac',
#   'area': '1,158 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'On Request',
#   'location': '2 BHK Flat in Vengaivasal, Medavakkam',
#   'price': '₹79.8 Lac',
#   'area': '1,331 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Pride Towers',
#   'location': '2 BHK Flat in Padur, Chennai',
#   'price': '₹82.3 Lac',
#   'area': '1,267 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Lifestyle Podium',
#   'location': '3 BHK Flat in T Nagar, Chennai',
#   'price': '₹4.9 Cr',
#   'area': '2,133 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'SPR Highliving District',
#   'location': '4 BHK Flat in Perambur, Chennai',
#   'price': '₹3.57 Cr',
#   'area': '2,596 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Arshiya',
#   'location': '3 BHK Flat in Kattupakkam, Chennai',
#   'price': '₹99.5 Lac',
#   'area': '1,411 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Sunskriti flats',
#   'location': '3 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹85.97 Lac',
#   'area': '1,246 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Residential Apartment',
#   'location': '3 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹83.66 Lac',
#   'area': '1,287 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Kundrathur, Chennai, Chennai South',
#   'location': '3 Bedroom House in Kundrathur, Chennai',
#   'price': '₹1.25 Cr',
#   'area': '800 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Gerugambakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in Gerugambakkam, Chennai',
#   'price': '₹1.45 Cr',
#   'area': '1,150 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Kovur, Chennai, Chennai West',
#   'location': '3 Bedroom House in Kovur, Chennai',
#   'price': '₹96 Lac',
#   'area': '800 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Hansa One Oh One',
#   'location': '3 BHK Flat in Nungambakkam, Chennai',
#   'price': '₹3.52 Cr',
#   'area': '1,772 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Residential Apartment',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹56.71 Lac',
#   'area': '1,031 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sanskriti flats',
#   'location': '3 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹79.21 Lac',
#   'area': '1,148 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Hansa One Oh One',
#   'location': '3 BHK Flat in Nungambakkam, Chennai',
#   'price': '₹3.5 Cr',
#   'area': '1,606 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Tower of Adyar by Nahar\n3.9',
#   'location': '4 BHK Flat in Adyar, Chennai',
#   'price': '₹3.74 Cr',
#   'area': '2,416 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Babu Residency',
#   'location': '3 BHK Flat in S Kolathur, Kovilambakkam',
#   'price': '₹98 Lac',
#   'area': '1,158 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Adhithya Residency',
#   'location': '3 BHK Flat in Kovilambakkam, Chennai',
#   'price': '₹93.79 Lac',
#   'area': '1,218 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Adhith enclave',
#   'location': '3 BHK Flat in Nanmangalam, Chennai',
#   'price': '₹90 Lac',
#   'area': '1,158 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Babu flats',
#   'location': '3 BHK Flat in Nanmangalam, Chennai',
#   'price': '₹95.7 Lac',
#   'area': '1,236 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Babu enclave',
#   'location': '3 BHK Flat in Kovilambakkam, Chennai',
#   'price': '₹93 Lac',
#   'area': '1,159 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'BABU FLATS',
#   'location': '3 BHK Flat in Rose Nagar, Kovilambakkam',
#   'price': '₹1.1 Cr',
#   'area': '1,218 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Valasaravakkam, Chennai, Chennai West',
#   'location': '6 Bedroom House in Valasaravakkam, Chennai',
#   'price': '₹4.9 Cr',
#   'area': '2,400 sqft',
#   'bhk': '6 BHK'},
#  {'name': 'Gerugambakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in Gerugambakkam, Chennai',
#   'price': '₹1.15 Cr',
#   'area': '800 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Lifestyle Podium',
#   'location': '4 BHK Flat in T Nagar, Chennai',
#   'price': '₹4.5 Cr',
#   'area': '2,601 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Ramapuram, Chennai',
#   'price': '₹1.4 Cr',
#   'area': '1,403 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Alapakkam, Porur, Chennai West',
#   'location': '6 Bedroom House in Alapakkam, Porur',
#   'price': '₹4.95 Cr',
#   'area': '2,400 sqft',
#   'bhk': '6 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Alapakkam, Porur',
#   'price': '₹96 Lac',
#   'area': '980 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Tower of Adyar by Nahar\n3.9',
#   'location': '4 BHK Flat in Adyar, Chennai',
#   'price': '₹3.74 Cr',
#   'area': '2,419 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Prosper',
#   'location': '2 BHK Flat in Thalambur, OMR',
#   'price': '₹67.8 Lac',
#   'area': '1,032 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '2 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹63.87 Lac',
#   'area': '900 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67.7 Lac',
#   'area': '970 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '2 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹74 Lac',
#   'area': '1,050 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RR SAI KEERTHI HOMES',
#   'location': '2 BHK Flat in Poonamallee, Chennai',
#   'price': '₹65 Lac',
#   'area': '956 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Rr sai keerthi homes',
#   'location': '2 BHK Flat in Poonamallee, Chennai',
#   'price': '₹65 Lac',
#   'area': '967 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi enclave Poonamallee',
#   'location': '2 BHK Flat in Poonamallee, Chennai',
#   'price': '₹65 Lac',
#   'area': '952 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '3 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹82 Lac',
#   'area': '1,170 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'RR sai mukesh flats',
#   'location': '2 BHK Flat in Poonamallee, Chennai',
#   'price': '₹65 Lac',
#   'area': '968 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67.85 Lac',
#   'area': '957 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67.25 Lac',
#   'area': '953 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '3 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹78 Lac',
#   'area': '1,186 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'keerthi homes',
#   'location': '3 BHK Flat in Poonamallee, Chennai',
#   'price': '₹1.1 Cr',
#   'area': '1,450 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Poonamallee, Chennai',
#   'price': '₹70 Lac',
#   'area': '885 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Poonamallee, Chennai',
#   'price': '₹77 Lac',
#   'area': '996 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Poonamallee, Chennai',
#   'price': '₹73 Lac',
#   'area': '937 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67.95 Lac',
#   'area': '976 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67.5 Lac',
#   'area': '958 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67 Lac',
#   'area': '953 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '2 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹63.87 Lac',
#   'area': '900 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '2 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹73.98 Lac',
#   'area': '1,050 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹68 Lac',
#   'area': '976 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '3 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹78 Lac',
#   'area': '1,187 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'sai anna baba flats',
#   'location': '2 BHK Flat in Gerugambakkam, Chennai',
#   'price': '₹75 Lac',
#   'area': '1,060 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹68 Lac',
#   'area': '975 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Sai keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67 Lac',
#   'area': '952 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹65 Lac',
#   'area': '975 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Gerugambakkam, Chennai',
#   'price': '₹74 Lac',
#   'area': '1,060 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹64 Lac',
#   'area': '957 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67 Lac',
#   'area': '975 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹64.5 Lac',
#   'area': '950 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RAKSHA HOMES',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹75.99 Lac',
#   'area': '1,070 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RAKSHA HOMES SAI KREETHI',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67.25 Lac',
#   'area': '975 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RAKSHA HOMES SAI KEERTHI',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67 Lac',
#   'area': '951 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RAKSHA HOMES',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹76 Lac',
#   'area': '1,060 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '2 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹63.87 Lac',
#   'area': '900 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '2 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹73.98 Lac',
#   'area': '1,050 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹68 Lac',
#   'area': '975 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67 Lac',
#   'area': '950 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '2 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹85.4 Lac',
#   'area': '980 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'ADHITHYA ENCLAVE',
#   'location': '3 BHK Flat in Kovilambakkam, Chennai',
#   'price': '₹91.5 Lac',
#   'area': '1,160 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGK Sri Sai Enclave',
#   'location': '2 BHK Flat in West Tambaram, Chennai South',
#   'price': '₹61 Lac',
#   'area': '962 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'lucky home new flat',
#   'location': '2 BHK Flat in Porur, Chennai',
#   'price': '₹76.79 Lac',
#   'area': '961 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Alapakkam, Porur',
#   'price': '₹1.32 Cr',
#   'area': '1,485 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'KG Ameya',
#   'location': '4 BHK Flat in Saidapet, GST Road',
#   'price': '₹4.5 Cr',
#   'area': '2,470 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'KG Ameya',
#   'location': '3 BHK Flat in Saidapet, GST Road',
#   'price': '₹3.1 Cr',
#   'area': '1,809 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGK Unity Kingdom',
#   'location': '2 BHK Flat in Medavakkam, Chennai',
#   'price': '₹72.21 Lac',
#   'area': '1,184 sqft',
#   'bhk': '2 BHK'},
#  {'name': "lake vista's",
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹70 Lac',
#   'area': '1,000 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Hiliving Serenity',
#   'location': '3 BHK Flat in Madhavaram, Chennai',
#   'price': '₹1.1 Cr',
#   'area': '1,300 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Hi Living seranity',
#   'location': '2 BHK Flat in Madhavaram, Chennai',
#   'price': '₹76 Lac',
#   'area': '1,022 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Ayana 95',
#   'location': '2 BHK Flat in Ayanambakkam, Chennai',
#   'price': '₹90 Lac',
#   'area': '1,022 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Ayana 95',
#   'location': '1 BHK Flat in Ayanambakkam, Chennai',
#   'price': '₹59 Lac',
#   'area': '501 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'ayana 95',
#   'location': '2 BHK Flat in Ayanambakkam, Chennai',
#   'price': '₹1.1 Cr',
#   'area': '1,143 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '4 BHK Flat in Guindy, Chennai South',
#   'price': '₹4.6 Cr',
#   'area': '3,739 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '3 BHK Flat in Guindy, Chennai South',
#   'price': '₹4.1 Cr',
#   'area': '1,968 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGK Summer Garden',
#   'location': '2 BHK Flat in Vengaivasal, Medavakkam',
#   'price': '₹69 Lac',
#   'area': '1,052 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'VGK Unity Kingdom',
#   'location': '2 BHK Flat in Medavakkam, Chennai',
#   'price': '₹84.75 Lac',
#   'area': '1,315 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Adroit House Of Ambal',
#   'location': '2 BHK Flat in Anna Salai, Chennai',
#   'price': '₹2.5 Cr',
#   'area': '1,232 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '1 BHK Flat in Mogappair, Chennai',
#   'price': '₹62 Lac',
#   'area': '682 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in West Tambaram, Chennai South',
#   'price': '₹55 Lac',
#   'area': '986 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Pacifica Aurum\n3.8',
#   'location': '3 BHK Flat in Padur, Chennai',
#   'price': '₹85 Lac',
#   'area': '1,463 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Pacifica Aurum\n3.8',
#   'location': '3 BHK Flat in Padur, Chennai',
#   'price': '₹85 Lac',
#   'area': '1,468 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Pacifica Aurum\n3.8',
#   'location': '2 BHK Flat in Padur, Chennai',
#   'price': '₹75 Lac',
#   'area': '1,261 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Pacifica Aurum\n3.8',
#   'location': '2 BHK Flat in Padur, Chennai',
#   'price': '₹75 Lac',
#   'area': '1,361 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Vriddhi',
#   'location': '3 BHK Flat in T Nagar, Chennai',
#   'price': '₹4.63 Cr',
#   'area': '2,174 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Vriddhi',
#   'location': '3 BHK Flat in T Nagar, Chennai',
#   'price': '₹3.95 Cr',
#   'area': '1,841 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGK Unity Kingdom',
#   'location': '3 BHK Flat in Medavakkam, Chennai',
#   'price': '₹91 Lac',
#   'area': '1,268 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Adyar, Chennai, Chennai South',
#   'location': '3 BHK Independent Builder Floor in Adyar, Chennai',
#   'price': '₹3.57 Cr',
#   'area': '1,948 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGK Summer Garden',
#   'location': '3 BHK Flat in Vengaivasal, Medavakkam',
#   'price': '₹83.13 Lac',
#   'area': '1,341 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '4 BHK Flat in Guindy, Chennai South',
#   'price': '₹4.9 Cr',
#   'area': '2,475 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Urbanrise Codename New Porur\n3.9',
#   'location': '2 BHK Flat in Thirumazhisai, Chennai',
#   'price': '₹49.14 Lac',
#   'area': '849 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Hi Living Evita',
#   'location': '3 BHK Flat in Madhavaram, Chennai',
#   'price': '₹1.3 Cr',
#   'area': '1,738 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Hi Living Evita',
#   'location': '3 BHK Flat in Madhavaram, Chennai',
#   'price': '₹1.05 Cr',
#   'area': '1,392 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'KG Ameya',
#   'location': '3 BHK Flat in Saidapet, GST Road',
#   'price': '₹2.89 Cr',
#   'area': '1,809 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Shriram Park 63\n3.8',
#   'location': '2 BHK Flat in Perungalathur, Chennai',
#   'price': '₹1 Cr',
#   'area': '1,385 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Ayyapakkam, Chennai, Chennai West',
#   'location': '4 Bedroom House in Ayyapakkam, Chennai',
#   'price': '₹1.4 Cr',
#   'area': '1,000 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'SRI SAI RAM FLATS',
#   'location': '2 BHK Flat in Porur Gardens, Chennai',
#   'price': '₹67.25 Lac',
#   'area': '957 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sri sai ram flats',
#   'location': '2 BHK Flat in Porur Gardens, Chennai',
#   'price': '₹67 Lac',
#   'area': '958 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹66.93 Lac',
#   'area': '957 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '2 BHK Flat in Maduravoyal, Chennai',
#   'price': '₹83 Lac',
#   'area': '860 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67 Lac',
#   'area': '952 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹64 Lac',
#   'area': '950 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'on Request',
#   'location': '2 BHK Flat in Mangadu, Chennai',
#   'price': '₹52.99 Lac',
#   'area': '818 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '4 BHK Flat in Guindy, Chennai South',
#   'price': '₹4.4 Cr',
#   'area': '2,475 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'bhaggyam vriddhi',
#   'location': '3 BHK Flat in T Nagar, Chennai',
#   'price': '₹3.41 Cr',
#   'area': '1,841 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Urbanrise Codename New Porur\n3.9',
#   'location': '2 BHK Flat in Thirumazhisai, Chennai',
#   'price': '₹45 Lac',
#   'area': '730 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Lifestyle Podium',
#   'location': '2 BHK Flat in T Nagar, Chennai',
#   'price': '₹4.9 Cr',
#   'area': '2,133 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Pacifica Pride Towers\n3.8',
#   'location': '2 BHK Flat in Padur, Chennai',
#   'price': '₹85 Lac',
#   'area': '1,358 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Urbanrise Revolution One',
#   'location': '2 BHK Flat in Padur, Chennai',
#   'price': '₹59 Lac',
#   'area': '888 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹67.1 Lac',
#   'area': '957 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'sai keerthi homes',
#   'location': '3 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹77.5 Lac',
#   'area': '1,186 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Sai keerthi homes',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹64.25 Lac',
#   'area': '957 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '2 BHK Flat in Ramapuram, Chennai',
#   'price': '₹96.9 Lac',
#   'area': '969 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Alapakkam, Porur',
#   'price': '₹1.23 Cr',
#   'area': '1,380 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '2 BHK Flat in Mogappair, Chennai',
#   'price': '₹1.45 Cr',
#   'area': '1,350 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '1 BHK Flat in Mogappair, Chennai',
#   'price': '₹63 Lac',
#   'area': '682 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'Maduravoyal, Chennai, Chennai West',
#   'location': '4 Bedroom House in Maduravoyal, Chennai',
#   'price': '₹2.85 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Vista Flats',
#   'location': '3 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹1.09 Cr',
#   'area': '1,204 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Hansa One Oh One',
#   'location': '3 BHK Flat in Nungambakkam, Chennai',
#   'price': '₹3.52 Cr',
#   'area': '1,772 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '3 BHK Flat in Guindy, Chennai South',
#   'price': '₹3.5 Cr',
#   'area': '1,968 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '4 BHK Flat in Guindy, Chennai South',
#   'price': '₹4.63 Cr',
#   'area': '3,501 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Urbanrise Codename New Porur\n3.9',
#   'location': '2 BHK Flat in Thirumazhisai, Chennai',
#   'price': '₹58 Lac',
#   'area': '849 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Urbanrise Codename New Porur\n3.9',
#   'location': '3 BHK Flat in Thirumazhisai, Chennai',
#   'price': '₹61 Lac',
#   'area': '885 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Hiliving Serenity',
#   'location': '2 BHK Flat in Madhavaram, Chennai',
#   'price': '₹74 Lac',
#   'area': '905 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'VGK Summer Garden',
#   'location': '2 BHK Flat in Vengaivasal, Medavakkam',
#   'price': '₹63.73 Lac',
#   'area': '1,028 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Raksha homes',
#   'location': '2 BHK Flat in Gerugambakkam, Chennai',
#   'price': '₹47 Lac',
#   'area': '646 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Navins Hanging Gardens\n3.8',
#   'location': '2 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹1.6 Cr',
#   'area': '974 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'On Request',
#   'location': '3 BHK Flat in Keelkattalai, Chennai',
#   'price': '₹1.3 Cr',
#   'area': '1,125 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '1 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹30 Lac',
#   'area': '420 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'RR RAKSHA HOMES',
#   'location': '1 BHK Flat in Kumananchavadi, Chennai',
#   'price': '₹30.03 Lac',
#   'area': '420 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'KG Ameya',
#   'location': '4 BHK Flat in Saidapet, GST Road',
#   'price': '₹3.71 Cr',
#   'area': '2,470 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'on Request',
#   'location': '3 BHK Flat in Saidapet, GST Road',
#   'price': '₹3.27 Cr',
#   'area': '2,333 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'sai keerthi',
#   'location': '3 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹78 Lac',
#   'area': '1,188 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'SAI KEERTHI HOMES',
#   'location': '3 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹75 Lac',
#   'area': '1,186 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'on request',
#   'location': '3 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹77.95 Lac',
#   'area': '1,180 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '3 BHK Flat in Guindy, Chennai South',
#   'price': '₹4.1 Cr',
#   'area': '1,968 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Navins Hanging Gardens\n3.8',
#   'location': '2 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹1.3 Cr',
#   'area': '1,005 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Urbanrise Codename New Porur\n3.8',
#   'location': '1 BHK Flat in Thirumazhisai, Chennai',
#   'price': '₹42 Lac',
#   'area': '633 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'Malles Ahaana',
#   'location': '1 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹48 Lac',
#   'area': '546 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'on request',
#   'location': '3 BHK Flat in Porur, Chennai',
#   'price': '₹77.85 Lac',
#   'area': '1,180 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Porur, Chennai',
#   'price': '₹67 Lac',
#   'area': '957 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'KG House of Champions',
#   'location': '2 BHK Flat in Perumbakkam, Chennai',
#   'price': '₹45 Lac',
#   'area': '796 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'KG House of Champions',
#   'location': '2 BHK Flat in Perumbakkam, Chennai',
#   'price': '₹46 Lac',
#   'area': '835 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Urbanrise Codename New Porur\n3.9',
#   'location': '3 BHK Flat in Thirumazhisai, Chennai',
#   'price': '₹51.22 Lac',
#   'area': '885 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Hiliving Serenity',
#   'location': '3 BHK Flat in Madhavaram, Chennai',
#   'price': '₹1 Cr',
#   'area': '1,275 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Shriram Park 63\n3.8',
#   'location': '2 BHK Flat in Perungalathur, Chennai',
#   'price': '₹98.01 Lac',
#   'area': '1,385 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '2 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹76.56 Lac',
#   'area': '880 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'residential apartment in siruseri',
#   'location': '2 BHK Flat in Siruseri Sipcot IT Park, Chennai',
#   'price': '₹58 Lac',
#   'area': '911 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Hansa One Oh One',
#   'location': '3 BHK Flat in Nungambakkam, Chennai',
#   'price': '₹3.5 Cr',
#   'area': '1,772 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'GP Homes Blazing Star',
#   'location': '3 BHK Flat in Porur, Chennai',
#   'price': '₹1.12 Cr',
#   'area': '1,405 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Residential Apartment',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹47.7 Lac',
#   'area': '852 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Anna baba new flat',
#   'location': '2 BHK Flat in Porur, Chennai',
#   'price': '₹67 Lac',
#   'area': '1,063 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Valasaravakkam, Chennai, Chennai West',
#   'location': '4 Bedroom House in Valasaravakkam, Chennai',
#   'price': '₹3.25 Cr',
#   'area': '1,400 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Urbanrise Codename New Porur\n3.9',
#   'location': '1 BHK Flat in Thirumazhisai, Chennai',
#   'price': '₹40 Lac',
#   'area': '633 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'Malles Ahaana',
#   'location': '1 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹48 Lac',
#   'area': '548 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'Hi Living Evita',
#   'location': '3 BHK Flat in Madhavaram, Chennai',
#   'price': '₹83 Lac',
#   'area': '1,155 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Malles Ahaana',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹76 Lac',
#   'area': '950 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'VGK Unity Kingdom',
#   'location': '2 BHK Flat in Medavakkam, Chennai',
#   'price': '₹61.55 Lac',
#   'area': '947 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'S M VILLA GERUGAMBAKKAM',
#   'location': '3 Bedroom House in Madanandapuram, Chennai',
#   'price': '₹1.57 Cr',
#   'area': '1,050 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Malles Ahaana',
#   'location': '3 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹91.62 Lac',
#   'area': '1,527 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '2 BHK Flat in Mogappair, Chennai',
#   'price': '₹1.17 Cr',
#   'area': '1,291 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '1 BHK Flat in Mogappair, Chennai',
#   'price': '₹60 Lac',
#   'area': '682 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'Propguider,Exurb',
#   'location': '1 BHK Flat in Thiruporur, OMR',
#   'price': '₹18 Lac',
#   'area': '395 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'Valasaravakkam, Chennai, Chennai West',
#   'location': '5 Bedroom House in Valasaravakkam, Chennai',
#   'price': '₹5 Cr',
#   'area': '2,400 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Hi Living Evita',
#   'location': '2 BHK Flat in Madhavaram, Chennai',
#   'price': '₹75 Lac',
#   'area': '962 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '2 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹76.55 Lac',
#   'area': '881 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Valasaravakkam, Chennai, Chennai West',
#   'location': '4 Bedroom House in Valasaravakkam, Chennai',
#   'price': '₹3.3 Cr',
#   'area': '1,401 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹1.22 Cr',
#   'area': '1,381 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Maduravoyal, Chennai, Chennai West',
#   'location': '4 Bedroom House in Maduravoyal, Chennai',
#   'price': '₹3.25 Cr',
#   'area': '1,401 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'RAKSHA HOMES',
#   'location': '2 BHK Flat in Gerugambakkam, Chennai',
#   'price': '₹78 Lac',
#   'area': '1,060 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Valasaravakkam, Chennai, Chennai West',
#   'location': '4 Bedroom House in Valasaravakkam, Chennai',
#   'price': '₹2.85 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '4 BHK Flat in Guindy, Chennai South',
#   'price': '₹3.03 Cr',
#   'area': '2,475 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Lancor Lumina Apartment',
#   'location': '3 BHK Flat in Guduvancheri, Chennai',
#   'price': '₹57 Lac',
#   'area': '925 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in Porur, Chennai',
#   'price': '₹66.9 Lac',
#   'area': '957 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Bollineni Zion',
#   'location': '2 BHK Flat in OMR, Chennai',
#   'price': '₹65 Lac',
#   'area': '910 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'VGK Unity Kingdom',
#   'location': '3 BHK Flat in Medavakkam, Chennai',
#   'price': '₹80.91 Lac',
#   'area': '1,245 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Olympia Opaline\n4.5',
#   'location': '3 BHK Flat in Navalur, Chennai',
#   'price': '₹1.2 Cr',
#   'area': '1,750 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'New Flat',
#   'location': '1 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹45.23 Lac',
#   'area': '521 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'Independent Apartment',
#   'location': '2 BHK Flat in Thiruvanmiyur, Chennai',
#   'price': '₹1.32 Cr',
#   'area': '1,015 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '1 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹45.24 Lac',
#   'area': '520 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'sri sai Ram Apartment',
#   'location': '2 BHK Flat in Porur Gardens, Chennai',
#   'price': '₹66 Lac',
#   'area': '816 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Sri sai ram Apartment',
#   'location': '2 BHK Flat in Porur Gardens, Chennai',
#   'price': '₹67 Lac',
#   'area': '860 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Ayyapakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in Ayyapakkam, Chennai',
#   'price': '₹98 Lac',
#   'area': '778 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'keerthi homes',
#   'location': '3 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹78 Lac',
#   'area': '1,186 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '2 BHK Flat in Mogappair, Chennai',
#   'price': '₹1 Cr',
#   'area': '1,062 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Casagrand First City\n3.8',
#   'location': '2 BHK Flat in Sholinganallur, Chennai',
#   'price': '₹75 Lac',
#   'area': '1,240 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Propguider, Aspires',
#   'location': '2 BHK Flat in Thalambur, OMR',
#   'price': '₹36.85 Lac',
#   'area': '970 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Navins Starwood Towers 2\n3.7',
#   'location': '3 BHK Flat in Medavakkam, Chennai',
#   'price': '₹1.04 Cr',
#   'area': '1,371 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Residential apartment in kelambakkam',
#   'location': '2 BHK Flat in Kelambakkam, Chennai',
#   'price': '₹48.51 Lac',
#   'area': '1,078 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Urbanrise The World of Joy',
#   'location': '3 BHK Flat in Siruseri, Chennai',
#   'price': '₹68 Lac',
#   'area': '1,086 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'KG House of Champions',
#   'location': '2 BHK Flat in Perumbakkam, Chennai',
#   'price': '₹50 Lac',
#   'area': '835 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'KG House of Champions',
#   'location': '2 BHK Flat in Perumbakkam, Chennai',
#   'price': '₹50 Lac',
#   'area': '817 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Shriram Park 63\n3.8',
#   'location': '3 BHK Flat in Perungalathur, Chennai',
#   'price': '₹96.41 Lac',
#   'area': '1,535 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'LML Iconia',
#   'location': '2 BHK Flat in Porur, Chennai',
#   'price': '₹60 Lac',
#   'area': '909 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'LML Iconia',
#   'location': '2 BHK Flat in Porur, Chennai',
#   'price': '₹62.5 Lac',
#   'area': '956 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Pragnya Eden Park\n4.2',
#   'location': '2 BHK Flat in OMR, Chennai',
#   'price': '₹70 Lac',
#   'area': '1,135 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Purva Somerset House',
#   'location': '3 BHK Flat in Guindy, Chennai South',
#   'price': '₹3.5 Cr',
#   'area': '1,890 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Adroit Prosper',
#   'location': '2 BHK Flat in Navalur, Chennai',
#   'price': '₹57 Lac',
#   'area': '1,054 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'RAKSHA HOMES Mukesh flats',
#   'location': '2 BHK Flat in Porur, Chennai',
#   'price': '₹75 Lac',
#   'area': '1,070 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Mukesh flat,new',
#   'location': '2 BHK Flat in Iyyappanthangal, Chennai',
#   'price': '₹57.75 Lac',
#   'area': '971 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Golden Opulence\n4.1',
#   'location': '3 BHK Flat in Poonamallee, Chennai',
#   'price': '₹95 Lac',
#   'area': '1,442 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹1.23 Cr',
#   'area': '1,380 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'New flat',
#   'location': '2 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹83 Lac',
#   'area': '861 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Brand New 3BHK Flat',
#   'location': '3 BHK Flat in Abhiramapuram, Chennai',
#   'price': '₹3.08 Cr',
#   'area': '1,400 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Maduravoyal, Chennai',
#   'price': '₹96 Lac',
#   'area': '980 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'om request',
#   'location': '3 BHK Flat in Porur, Chennai',
#   'price': '₹77.95 Lac',
#   'area': '1,180 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Urbanrise Revolution One',
#   'location': '1 BHK Flat in Padur, Chennai',
#   'price': '₹36 Lac',
#   'area': '525 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'prop guider , aria.',
#   'location': '2 BHK Flat in Tambaram, Chennai',
#   'price': '₹45 Lac',
#   'area': '1,001 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Tower of Adyar by Nahar\n3.9',
#   'location': '4 BHK Flat in Adyar, Chennai',
#   'price': '₹3.3 Cr',
#   'area': '2,380 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Shanthi Colony, Anna Nagar',
#   'price': '₹2.9 Cr',
#   'area': '1,300 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Adroit House Of Ambal',
#   'location': '3 BHK Flat in Anna Salai, Chennai',
#   'price': '₹3.45 Cr',
#   'area': '1,723 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Malles Ahaana',
#   'location': '3 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹90.54 Lac',
#   'area': '1,509 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Kattupakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in Kattupakkam, Chennai',
#   'price': '₹1.65 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGN Prathish Avenue, Kolapakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in VGN Prathish Avenue, Kolapakkam, Chennai',
#   'price': '₹1.6 Cr',
#   'area': '1,000 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGN Prathish Avenue, Kolapakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in VGN Prathish Avenue, Kolapakkam, Chennai',
#   'price': '₹1.45 Cr',
#   'area': '950 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'on request',
#   'location': '2 BHK Flat in West Tambaram, Chennai South',
#   'price': '₹55 Lac',
#   'area': '1,011 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Gerugambakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in Gerugambakkam, Chennai',
#   'price': '₹88 Lac',
#   'area': '800 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Kattupakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in Kattupakkam, Chennai',
#   'price': '₹1.45 Cr',
#   'area': '1,140 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Gerugambakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in Gerugambakkam, Chennai',
#   'price': '₹1.15 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Fomra Hues\n4.0',
#   'location': '3 BHK Flat in Porur, Chennai',
#   'price': '₹1.15 Cr',
#   'area': '1,525 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGN Southern Avenue\n3.8',
#   'location': '3 BHK Flat in Potheri, Kattankulathur',
#   'price': '₹65 Lac',
#   'area': '1,384 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Malles Ahaana',
#   'location': '3 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹95 Lac',
#   'area': '1,189 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGK Sai Hardik',
#   'location': '2 BHK Flat in East Tambaram, Chennai',
#   'price': '₹55 Lac',
#   'area': '1,228 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Independent floor,new',
#   'location': '3 BHK Independent Builder Floor in Adambakkam, Chennai',
#   'price': '₹1.95 Cr',
#   'area': '1,850 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Mahalakshmi Nagar Annexe, Mugalivakkam, Chennai, Chennai West',
#   'location': '4 Bedroom House in Mahalakshmi Nagar Annexe, Mugalivakkam, Chennai',
#   'price': '₹1.35 Cr',
#   'area': '1,350 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Ayanambakkam, Chennai, Chennai North',
#   'location': '3 Bedroom House in Ayanambakkam, Chennai',
#   'price': '₹98 Lac',
#   'area': '775 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '3 BHK Flat in Mogappair, Chennai',
#   'price': '₹1.6 Cr',
#   'area': '1,880 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '2 BHK Flat in Mogappair, Chennai',
#   'price': '₹1 Cr',
#   'area': '1,270 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Brigade Xanadu\n4.0',
#   'location': '3 BHK Flat in Mogappair, Chennai',
#   'price': '₹1.29 Cr',
#   'area': '1,364 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Pacifica Pride Towers\n3.8',
#   'location': '3 BHK Flat in Padur, Chennai',
#   'price': '₹85.44 Lac',
#   'area': '1,441 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Arun Excello Urmika',
#   'location': '2 BHK Flat in Guduvancheri, Chennai',
#   'price': '₹27 Lac',
#   'area': '590 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Risland The Ace',
#   'location': '2 BHK Flat in Perungudi, Chennai',
#   'price': '₹1.05 Cr',
#   'area': '867 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Incor PBEL City',
#   'location': '2 BHK Flat in Kelambakkam, Chennai',
#   'price': '₹42.72 Lac',
#   'area': '1,068 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Propguider,Jubilee Residences',
#   'location': '1 BHK Flat in Guduvancheri, Chennai',
#   'price': '₹18.96 Lac',
#   'area': '480 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'KG House of Champions',
#   'location': '2 BHK Flat in Perumbakkam, Chennai',
#   'price': '₹33.42 Lac',
#   'area': '796 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'KG House of Champions',
#   'location': '2 BHK Flat in Perumbakkam, Chennai',
#   'price': '₹33.59 Lac',
#   'area': '840 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Guduvancheri, Chennai, Chennai South',
#   'location': '3 Bedroom House in Guduvancheri, Chennai',
#   'price': '₹73 Lac',
#   'area': '900 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Risland The Ace',
#   'location': '2 BHK Flat in Perungudi, Chennai',
#   'price': '₹1.06 Cr',
#   'area': '1,187 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Risland The Ace',
#   'location': '1 BHK Flat in Perungudi, Chennai',
#   'price': '₹53.58 Lac',
#   'area': '600 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'e residence, anna salai, royapettah',
#   'location': '1 BHK Flat in Royapettah, Chennai',
#   'price': '₹1.14 Cr',
#   'area': '600 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'RAKSHA HOMES VIGNESH FLATS',
#   'location': '2 BHK Flat in Mugalivakkam, Chennai',
#   'price': '₹49 Lac',
#   'area': '800 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Dhanalaxmi Homes',
#   'location': '3 BHK Flat in Nanganallur, Chennai',
#   'price': '₹1.92 Cr',
#   'area': '1,746 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Esha Akshayam',
#   'location': '3 BHK Flat in Nanganallur, Chennai',
#   'price': '₹1.28 Cr',
#   'area': '1,161 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Aadhira flats',
#   'location': '3 BHK Flat in Nanganallur, Chennai',
#   'price': '₹2.13 Cr',
#   'area': '1,771 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Dwaraka flats',
#   'location': '2 BHK Flat in Adambakkam, Chennai',
#   'price': '₹92.61 Lac',
#   'area': '842 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Dwaraka flats',
#   'location': '3 BHK Flat in Adambakkam, Chennai',
#   'price': '₹1.2 Cr',
#   'area': '1,093 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Thai Sarvaya flats',
#   'location': '3 BHK Flat in Adambakkam, Chennai',
#   'price': '₹1.15 Cr',
#   'area': '1,155 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Yadavi flats',
#   'location': '2 BHK Flat in Adambakkam, Chennai',
#   'price': '₹79.37 Lac',
#   'area': '882 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'M.M.enclave',
#   'location': '3 BHK Flat in Adambakkam, Chennai',
#   'price': '₹1 Cr',
#   'area': '1,152 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'M.M.enclave',
#   'location': '2 BHK Flat in Adambakkam, Chennai',
#   'price': '₹65.1 Lac',
#   'area': '744 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'M.M.enclave',
#   'location': '3 BHK Flat in Adambakkam, Chennai',
#   'price': '₹1.25 Cr',
#   'area': '1,442 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'M.M.enclave',
#   'location': '3 BHK Flat in Adambakkam, Chennai',
#   'price': '₹1.08 Cr',
#   'area': '1,240 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Valasaravakkam, Chennai',
#   'price': '₹1.32 Cr',
#   'area': '1,465 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Emami Tejomaya\n4.0',
#   'location': '2 BHK Flat in Navalur, Chennai',
#   'price': '₹65 Lac',
#   'area': '734 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Gerugambakkam, Chennai, Chennai West',
#   'location': '2 Bedroom House in Gerugambakkam, Chennai',
#   'price': '₹85 Lac',
#   'area': '940 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Doshi Euphoria\n3.5',
#   'location': '2 BHK Flat in Perungudi, Chennai',
#   'price': '₹63.9 Lac',
#   'area': '785 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Doshi Euphoria\n3.5',
#   'location': '1 BHK Flat in Perungudi, Chennai',
#   'price': '₹40 Lac',
#   'area': '415 sqft',
#   'bhk': '1 BHK'},
#  {'name': 'S m villa Gerugambakkam',
#   'location': '3 Bedroom House in Porur, Chennai',
#   'price': '₹1.6 Cr',
#   'area': '1,130 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Prime Flat',
#   'location': '2 BHK Flat in Anna Nagar, Chennai',
#   'price': '₹1.2 Cr',
#   'area': '920 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'lucky home new',
#   'location': '2 BHK Flat in Porur, Chennai',
#   'price': '₹65.9 Lac',
#   'area': '824 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'New Flat',
#   'location': '3 BHK Flat in Shanthi Colony, Anna Nagar',
#   'price': '₹2.95 Cr',
#   'area': '1,711 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'TDC VATIKA',
#   'location': '3 BHK Flat in Bhuvaneshwari Nagar, Velachery',
#   'price': '₹69 Lac',
#   'area': '990 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Malles Ahaana',
#   'location': '2 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹65 Lac',
#   'area': '989 sqft',
#   'bhk': '2 BHK'},
#  {'name': "lake vista's",
#   'location': '3 BHK Flat in Pallikaranai, Chennai',
#   'price': '₹1.2 Cr',
#   'area': '2,139 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Moulivakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in Moulivakkam, Chennai',
#   'price': '₹1.4 Cr',
#   'area': '900 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'VGN Lakshmi Nagar, Mugalivakkam, Chennai, Chennai West',
#   'location': '3 Bedroom House in VGN Lakshmi Nagar, Mugalivakkam, Chennai',
#   'price': '₹1.25 Cr',
#   'area': '700 sqft',
#   'bhk': '3 BHK'}]

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                   name  \
# 0                                           on request
# 1                                             RC Adena
# 2                                     Radiance Suprema
# 3                                           on request
# 4                                 Shriram Park 63\n3.8
# ..                                                 ...
# 291                                         TDC VATIKA
# 292                                      Malles Ahaana
# 293                                       lake vista's
# 294                 Moulivakkam, Chennai, Chennai West
# 295  VGN Lakshmi Nagar, Mugalivakkam, Chennai, Chen...
#
#                                               location      price        area  \
# 0                  2 BHK Flat in Pallikaranai, Chennai    ₹48 Lac    764 sqft
# 1              2 BHK Flat in Thirumullaivoyal, Chennai    ₹45 Lac    820 sqft
# 2                    2 BHK Flat in Madhavaram, Chennai      ₹1 Cr  1,102 sqft
# 3                  2 BHK Flat in Pallikaranai, Chennai  ₹57.7 Lac    932 sqft
# 4                 3 BHK Flat in Perungalathur, Chennai    ₹1.5 Cr  1,970 sqft
# ..                                                 ...        ...         ...
# 291       3 BHK Flat in Bhuvaneshwari Nagar, Velachery    ₹69 Lac    990 sqft
# 292                2 BHK Flat in Pallikaranai, Chennai    ₹65 Lac    989 sqft
# 293                3 BHK Flat in Pallikaranai, Chennai    ₹1.2 Cr  2,139 sqft
# 294            3 Bedroom House in Moulivakkam, Chennai    ₹1.4 Cr    900 sqft
# 295  3 Bedroom House in VGN Lakshmi Nagar, Mugaliva...   ₹1.25 Cr    700 sqft
#
#        bhk
# 0    2 BHK
# 1    2 BHK
# 2    2 BHK
# 3    2 BHK
# 4    3 BHK
# ..     ...
# 291  3 BHK
# 292  2 BHK
# 293  3 BHK
# 294  3 BHK
# 295  3 BHK
#
# [296 rows x 5 columns]

# %%
df.to_excel("raw_chennai.xlsx")
